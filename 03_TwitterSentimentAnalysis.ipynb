# %% [markdown]
# # Split files and compute sentiment scores

# %%
from time import sleep
import json
import pandas as pd
import io
from tqdm import tqdm

PRICE_FOLDER    = "data/price/"
TWITTER_FOLDER  = "data/twitter/"
tweets_raw_file = './data/twitter/bitcoin_tweets_raw.csv'
tweets_clean_file = './data/twitter/bitcoin_tweets_clean.csv'

# %%
df_clean = pd.read_csv(tweets_clean_file,low_memory=False)
print(df_clean.shape)
df_clean.head(5)
# Out:
# (635826, 9)
#   Unnamed: 0            ID                                             Tweets  \
# 0        0.0  1.437210e+18            nioctiBmaxi Gib me cheaper bitcoin Baki
# 1        1.0  1.437230e+18  BARBARABURGSTA1 john_faidutti So much pain las...
# 2        1.0  1.437240e+18  📄 Transaction Report\n🖥 GMO Coin\n🕚 2021-09-13...
# 3        0.0  1.437260e+18  ZaringDavid 3% of Tether reserves is cash.  Pe...
# 4        0.0  1.437280e+18  United States Money supply since 1960 - 2021 ....
#
#    Likes Retweets  Followers     CreatedAt          Hour      NextHour
# 0    0.0        0      206.0  13/9/21 0:40  13/9/21 0:00  13/9/21 1:00
# 1    0.0        0     3546.0  13/9/21 1:40  13/9/21 1:00  13/9/21 2:00
# 2    0.0        0       83.0  13/9/21 2:40  13/9/21 2:00  13/9/21 3:00
# 3    0.0        0       15.0  13/9/21 3:40  13/9/21 3:00  13/9/21 4:00
# 4    0.0        0       53.0  13/9/21 4:40  13/9/21 4:00  13/9/21 5:00

# %%
# Drop na values
df_clean = df_clean.dropna()
# Manage data types
df_clean = df_clean.astype({"Likes": int, "Retweets": float, "Followers": int})
df_clean = df_clean.astype({"Retweets": int})

# %% [markdown]
# # Sentiment analysis

# %% [markdown]
# VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media.
#
# VADER takes into account
# - negations and contractions (not good, wasn’t good)
# - Punctuation (good!!!), CAPS, emotes :), emojis
# - Intensificators (very, kind of), acronyms ‘lol’
# - Scores between -1.0 (negative) and 1.0 (positive)
#
# We will use this sentiment analysis of the tweets to calculate a score that will represent the importance of each tweet.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()
compound = []
for i,s in enumerate(tqdm(df_clean['Tweets'])):
    vs = analyzer.polarity_scores(s)
    compound.append(vs["compound"])
df_clean["compound"] = compound
df_clean.head(5)
# Out:
# 100%|██████████| 635821/635821 [02:40<00:00, 3971.15it/s]
#   Unnamed: 0            ID                                             Tweets  \
# 0        0.0  1.437210e+18            nioctiBmaxi Gib me cheaper bitcoin Baki
# 1        1.0  1.437230e+18  BARBARABURGSTA1 john_faidutti So much pain las...
# 2        1.0  1.437240e+18  📄 Transaction Report\n🖥 GMO Coin\n🕚 2021-09-13...
# 3        0.0  1.437260e+18  ZaringDavid 3% of Tether reserves is cash.  Pe...
# 4        0.0  1.437280e+18  United States Money supply since 1960 - 2021 ....
#
#    Likes Retweets  Followers     CreatedAt          Hour      NextHour  \
# 0    0.0        0      206.0  13/9/21 0:40  13/9/21 0:00  13/9/21 1:00
# 1    0.0        0     3546.0  13/9/21 1:40  13/9/21 1:00  13/9/21 2:00
# 2    0.0        0       83.0  13/9/21 2:40  13/9/21 2:00  13/9/21 3:00
# 3    0.0        0       15.0  13/9/21 3:40  13/9/21 3:00  13/9/21 4:00
# 4    0.0        0       53.0  13/9/21 4:40  13/9/21 4:00  13/9/21 5:00
#
#    compound
# 0    0.0000
# 1   -0.5407
# 2    0.0000
# 3    0.0953
# 4    0.2467

# %% [markdown]
# ## Calculate a score for each tweet
#
# To calculate the score for each tweet, we use different variables to which we had a weight based on its importance.
#
# The compound column represents the sentiment of the tweets and its value is between -1 and 1.
#
# We also use the number of retweets, the number of likes, and the number of users that follow the tweet's author.

# %%
import math

scores = []

for i, s in tqdm(df_clean.iterrows(), total=df_clean.shape[0]):
    scores.append(s["compound"] * ((int(s["Followers"]))) * ((int(s["Likes"])+1)) * ((int(s["Retweets"])+1)))

df_clean["score"] = scores
df_clean.head(20)
# Out:
# 100%|██████████| 635821/635821 [01:46<00:00, 5970.94it/s]
#    Unnamed: 0            ID  \
# 0         0.0  1.437210e+18
# 1         1.0  1.437230e+18
# 2         1.0  1.437240e+18
# 3         0.0  1.437260e+18
# 4         0.0  1.437280e+18
# 5         5.0  1.437270e+18
# 6         1.0  1.437290e+18
# 7         0.0  1.437310e+18
# 8        32.0  1.437300e+18
# 9         0.0  1.437320e+18
# 10        0.0  1.437340e+18
# 11       61.0  1.437330e+18
# 12        0.0  1.437350e+18
# 13        0.0  1.437370e+18
# 14       82.0  1.437360e+18
# 15        0.0  1.437380e+18
# 16        0.0  1.437400e+18
# 17        0.0  1.437410e+18
# 18        0.0  1.437430e+18
# 19        0.0  1.437440e+18
#
#                                                Tweets  Likes  Retweets  \
# 0             nioctiBmaxi Gib me cheaper bitcoin Baki      0         0
# 1   BARBARABURGSTA1 john_faidutti So much pain las...      0         0
# 2   📄 Transaction Report\n🖥 GMO Coin\n🕚 2021-09-13...      0         0
# 3   ZaringDavid 3% of Tether reserves is cash.  Pe...      0         0
# 4   United States Money supply since 1960 - 2021 ....      0         0
# 5   i'm more excited about $ADA ecosystem integrat...      0         0
# 6   janeygak Follow diopfode , he will launch a co...      0         0
# 7   Bitcoin Millionaires Purchase 50,000 $BTC in t...      0         0
# 8   markjeffrey I don’t want to sound rude but it’...      1         0
# 9   vuyo_gabriel Hey I joined a network called Sur...      0         0
# 10  BTC $BTC  Hopium for the Bitcoin bulls\n\n/3Bb...      0         0
# 11  A beautiful week starts at /Z0KRe09JGC where y...      3         1
# 12  Billionaire Investor Warns ‘Be Very Careful’ A...      0         0
# 13  NFTs could work wonders for the pandemic-hit m...      0         0
# 14  1Cryptoking1 Dxron2 His exact words were i don...      0         0
# 15  Bitcoin whales on the move. Are they fishing f...      0         0
# 16  Michael Saylor’s MicroStrategy Buys 5,050 More...      0         0
# 17  CoinMarketCap Over 88%+ Profits within 1 hour ...      0         0
# 18  DianaOrrock I am in no way a "bitcoin fixes th...      0         0
# 19  mstrade glassnode Bitcoin is a true leader of ...      0         0
#
#     Followers      CreatedAt           Hour       NextHour  compound  \
# 0         206   13/9/21 0:40   13/9/21 0:00   13/9/21 1:00    0.0000
# 1        3546   13/9/21 1:40   13/9/21 1:00   13/9/21 2:00   -0.5407
# 2          83   13/9/21 2:40   13/9/21 2:00   13/9/21 3:00    0.0000
# 3          15   13/9/21 3:40   13/9/21 3:00   13/9/21 4:00    0.0953
# 4          53   13/9/21 4:40   13/9/21 4:00   13/9/21 5:00    0.2467
# 5         157   13/9/21 4:40   13/9/21 4:00   13/9/21 5:00    0.4005
# 6         452   13/9/21 5:40   13/9/21 5:00   13/9/21 6:00    0.0772
# 7        6521   13/9/21 6:40   13/9/21 6:00   13/9/21 7:00    0.0000
# 8         971   13/9/21 6:39   13/9/21 6:00   13/9/21 7:00   -0.2144
# 9         387   13/9/21 7:40   13/9/21 7:00   13/9/21 8:00    0.8118
# 10        247   13/9/21 8:40   13/9/21 8:00   13/9/21 9:00    0.0000
# 11         49   13/9/21 8:39   13/9/21 8:00   13/9/21 9:00    0.6808
# 12        127   13/9/21 9:40   13/9/21 9:00  13/9/21 10:00   -0.1027
# 13         19  13/9/21 10:40  13/9/21 10:00  13/9/21 11:00    0.4939
# 14         65  13/9/21 10:38  13/9/21 10:00  13/9/21 11:00    0.7351
# 15       9409  13/9/21 11:40  13/9/21 11:00  13/9/21 12:00    0.0000
# 16      35671  13/9/21 12:40  13/9/21 12:00  13/9/21 13:00    0.0000
# 17         56  13/9/21 13:40  13/9/21 13:00  13/9/21 14:00    0.7351
# 18       4736  13/9/21 14:40  13/9/21 14:00  13/9/21 15:00   -0.2960
# 19         24  13/9/21 15:40  13/9/21 15:00  13/9/21 16:00    0.4753
#
#         score
# 0      0.0000
# 1  -1917.3222
# 2      0.0000
# 3      1.4295
# 4     13.0751
# 5     62.8785
# 6     34.8944
# 7      0.0000
# 8   -416.3648
# 9    314.1666
# 10     0.0000
# 11   266.8736
# 12   -13.0429
# 13     9.3841
# 14    47.7815
# 15     0.0000
# 16     0.0000
# 17    41.1656
# 18 -1401.8560
# 19    11.4072

# %% [markdown]
# ## Group by

# %%
# Group by hourly sum of scores
sent = df_clean.groupby('Hour')['score'].sum()
comp = df_clean.groupby('Hour')['compound'].sum()
n = df_clean.groupby('Hour')['Tweets'].count()
likes = df_clean.groupby('Hour')['Likes'].sum()
retweets = df_clean.groupby('Hour')['Retweets'].sum()

sent = pd.Series.to_frame(sent)
comp = pd.Series.to_frame(comp)
n = pd.Series.to_frame(n)
likes = pd.Series.to_frame(likes)
retweets = pd.Series.to_frame(retweets)

conc = pd.concat([n, likes, retweets, comp, sent], axis=1)

# %%
# Set index as datetime
conc.index = pd.to_datetime(conc.index)
# Sort by time
conc = conc.sort_index()

# %% [markdown]
# ## Export to csv

# %%
twitter_sentiment_file = './data/twitter/bitcoin_twitter_sentiment.csv'

conc.to_csv(twitter_sentiment_file, mode='a', encoding='utf-8',index=True,header=True)
